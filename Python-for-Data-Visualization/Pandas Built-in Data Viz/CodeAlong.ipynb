# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.rcParams['patch.force_edgecolor'] = True
sns.set_style('whitegrid')

# %%
df1 = pd.read_csv('df1', index_col=0)

# %%
df1.head(1)
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233

# %%
df2 = pd.read_csv('df2')

# %%
df2.head(1)
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904

# %%
df3 = pd.read_csv('df3')

# %%
df3.head(1)
# Out:
#           a         b        c         d
# 0  0.336272  0.325011  0.00102  0.401402

# %%
df1['A'].hist(bins=30)

# %%
df1['A'].plot(kind='hist', bins=50)

# %%
df1['A'].plot.hist(bins=20)

# %%
df2.plot.area(alpha=0.4)

# %%
df2.plot.bar()

# %%
df2.plot.bar(stacked=True)

# %%
df1['A'].plot.hist(bins=50)

# %%
df1.plot.line(x=df1.index, y='B', figsize=(12,3))

# %%
df1.plot.scatter(x='A', y='B', c='C', cmap='coolwarm')

# %%
df1.plot.scatter(x='A', y='B', s=df1['C'].values*100)
# Out:
# C:\Users\Administrator\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\matplotlib\collections.py:877: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
df2.plot.box()

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns=['a','b'])

# %%
df.plot.hexbin(x='a', y='b',gridsize=25, cmap='magma')

# %%
df2['a'].plot.kde()

# %%
df2['a'].plot.density()

# %%
df2.plot.kde()
