# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline
sns.set_style('whitegrid')

# %%
from sklearn.datasets import load_breast_cancer

# %%
cancer = load_breast_cancer()

# %%
cancer.keys()
# Out:
# dict_keys(['target_names', 'feature_names', 'data', 'DESCR', 'target'])

# %%
df = pd.DataFrame(cancer['data'], columns=cancer['feature_names'])

# %%
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension           ...             worst radius  \
# ...

# %%
y = cancer['target']

# %%
cancer['target_names']
# Out:
# array(['malignant', 'benign'], dtype='<U9')

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_scale = scaler.fit_transform(df)

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)

# %%
X_pca = pca.fit_transform(X_scale)

# %%
plt.scatter(X[:,0], X[:,1], c=cancer['target'], cmap='coolwarm')

# %%
pca_comp = pd.DataFrame(pca.components_, columns=cancer['feature_names'], index=cancer['target_names'])

# %%
pca_comp.head()
# Out:
#            mean radius  mean texture  mean perimeter  mean area  \
# malignant     0.218902      0.103725        0.227537   0.220995
# benign       -0.233857     -0.059706       -0.215181  -0.231077
#
#            mean smoothness  mean compactness  mean concavity  \
# malignant         0.142590          0.239285        0.258400
# benign            0.186113          0.151892        0.060165
#
#            mean concave points  mean symmetry  mean fractal dimension  \
# malignant             0.260854       0.138167                0.064363
# benign               -0.034768       0.190349                0.366575
#
#                     ...             worst radius  worst texture  \
# malignant           ...                 0.227997       0.104469
# benign              ...                -0.219866      -0.045467
#
#            worst perimeter  worst area  worst smoothness  worst compactness  \
# malignant         0.236640    0.224871          0.127953           0.210096
# ...

# %%
plt.figure(figsize=(20,5))
sns.heatmap(data=pca_comp, cmap='plasma', annot=True)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scale, y, test_size=0.3)

# %%
from sklearn.svm import SVC

# %%
svm = SVC()

# %%
svm.fit(X_train,y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
svm.score(X_test,y_test)
# Out:
# 0.9824561403508771

# %%
errors = []
c_range = range(1,df.shape[1])
best_error = 999
best_c = 0
y_pred = None


for c in c_range:
    X_pca = PCA(n_components=c).fit_transform(X_scale)
    X_train, X_test, y_train, y_test = train_test_split(X_pca, y, test_size=0.3)
    svm = SVC()
    svm.fit(X_train,y_train)
    y_pred = svm.predict(X_test)
    error = 1 - svm.score(X_test,y_test)
    
    if (error < best_error):
        best_error = error
        best_c = c
        y_pred = y_pred
    
    errors.append(error)
    
plt.plot(c_range, errors)
